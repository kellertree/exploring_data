# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\data_\appdata\local\programs\python\python312\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\data_\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/125.4 kB ? eta -:--:--
#    ------------------- ------------------- 61.4/125.4 kB 825.8 kB/s eta 0:00:01
#    ---------------------------------------  122.9/125.4 kB 1.2 MB/s eta 0:00:01
#    -------------------------------------- 125.4/125.4 kB 921.6 kB/s eta 0:00:00
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.15.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.7.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting jinja2>=2.9 (from folium)
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting numpy (from folium)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 540.4 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\data_\appdata\local\programs\python\python312\lib\site-packages (from folium) (2.31.0)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2023.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\data_\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\data_\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\data_\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\data_\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2024.2.2)
# Downloading folium-0.15.1-py2.py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.0 kB ? eta -:--:--
#    ------------------------------------- -- 92.2/97.0 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 97.0/97.0 kB 1.8 MB/s eta 0:00:00
# Downloading branca-0.7.1-py3-none-any.whl (25 kB)
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.2 kB ? eta -:--:--
#    ---------------------------------------- 133.2/133.2 kB 3.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.5 MB 4.2 MB/s eta 0:00:04
#    ---------------------------------------- 0.2/15.5 MB 2.1 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/15.5 MB 3.4 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/15.5 MB 4.6 MB/s eta 0:00:04
#    -- ------------------------------------- 1.2/15.5 MB 4.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.7/15.5 MB 6.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.2/15.5 MB 6.6 MB/s eta 0:00:03
#    ------ --------------------------------- 2.6/15.5 MB 7.2 MB/s eta 0:00:02
#    -------- ------------------------------- 3.3/15.5 MB 8.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.9/15.5 MB 8.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.0/15.5 MB 8.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/15.5 MB 8.3 MB/s eta 0:00:02
#    ------------ --------------------------- 4.8/15.5 MB 8.0 MB/s eta 0:00:02
#    ------------- -------------------------- 5.3/15.5 MB 8.2 MB/s eta 0:00:02
#    --------------- ------------------------ 6.0/15.5 MB 8.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.6/15.5 MB 9.0 MB/s eta 0:00:01
#    ------------------- -------------------- 7.4/15.5 MB 9.5 MB/s eta 0:00:01
#    --------------------- ------------------ 8.2/15.5 MB 9.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.6/15.5 MB 9.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.1/15.5 MB 9.9 MB/s eta 0:00:01
#    ------------------------- -------------- 10.0/15.5 MB 10.3 MB/s eta 0:00:01
#    --------------------------- ------------ 10.7/15.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.2/15.5 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 11.8/15.5 MB 12.1 MB/s eta 0:00:01
#    ------------------------------- -------- 12.1/15.5 MB 11.7 MB/s eta 0:00:01
#    --------------------------------- ------ 13.0/15.5 MB 12.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.7/15.5 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.4/15.5 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.5 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 13.4 MB/s eta 0:00:00
# Downloading xyzservices-2023.10.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.3 kB ? eta -:--:--
#    ---------------------------------------- 56.3/56.3 kB 3.1 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Installing collected packages: xyzservices, numpy, MarkupSafe, jinja2, branca, folium
# Successfully installed MarkupSafe-2.1.5 branca-0.7.1 folium-0.15.1 jinja2-3.1.3 numpy-1.26.4 xyzservices-2023.10.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\data_\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    -------------------------- ------------- 41.0/62.6 kB 960.0 kB/s eta 0:00:01
#    ---------------------------------------- 62.6/62.6 kB 1.1 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    ----------------------------------- ---- 143.4/163.8 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 163.8/163.8 kB 2.5 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB 6.0 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.6 kB ? eta -:--:--
#    ---------------------------------------- 61.6/61.6 kB ? eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ---------------------------------------- 121.1/121.1 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.6 requests-2.31.0 urllib3-2.2.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\data_\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from bs4 import BeautifulSoup
import requests
import folium

# %%
url = 'https://en.wikipedia.org/wiki/List_of_counties_in_Wisconsin'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
links = soup.find_all('a')

# %%
for link in links:
    print(link.get('href'))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=List+of+counties+in+Wisconsin
# /w/index.php?title=Special:UserLogin&returnto=List+of+counties+in+Wisconsin
# /w/index.php?title=Special:CreateAccount&returnto=List+of+counties+in+Wisconsin
# /w/index.php?title=Special:UserLogin&returnto=List+of+counties+in+Wisconsin
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Governance
# #List_of_counties
# #Renamed_counties
# #Proposed_counties
# #See_also
# #References
# #External_links
# https://bar.wikipedia.org/wiki/Countys_in_Wisconsin
# https://ca.wikipedia.org/wiki/Llista_de_comtats_de_Wisconsin
# https://cy.wikipedia.org/wiki/Rhestr_o_Siroedd_Wisconsin
# https://de.wikipedia.org/wiki/Liste_der_Countys_in_Wisconsin
# https://et.wikipedia.org/wiki/Wisconsini_maakondade_loend
# https://es.wikipedia.org/wiki/Anexo:Condados_de_Wisconsin
# https://fr.wikipedia.org/wiki/Comt%C3%A9s_de_l%27%C3%89tat_du_Wisconsin
# https://ga.wikipedia.org/wiki/Contaetha_in_Wisconsin
# https://ko.wikipedia.org/wiki/%EC%9C%84%EC%8A%A4%EC%BD%98%EC%8B%A0%EC%A3%BC%EC%9D%98_%EA%B5%B0_%EB%AA%A9%EB%A1%9D
# https://is.wikipedia.org/wiki/S%C3%BDslur_%C3%AD_Wisconsin
# https://it.wikipedia.org/wiki/Contee_del_Wisconsin
# https://he.wikipedia.org/wiki/%D7%9E%D7%97%D7%95%D7%96%D7%95%D7%AA_%D7%95%D7%99%D7%A1%D7%A7%D7%95%D7%A0%D7%A1%D7%99%D7%9F
# https://hu.wikipedia.org/wiki/Wisconsin_megy%C3%A9inek_list%C3%A1ja
# https://nl.wikipedia.org/wiki/Lijst_van_county%27s_in_Wisconsin
# https://ja.wikipedia.org/wiki/%E3%82%A6%E3%82%A3%E3%82%B9%E3%82%B3%E3%83%B3%E3%82%B7%E3%83%B3%E5%B7%9E%E3%81%AE%E9%83%A1%E4%B8%80%E8%A6%A7
# https://frr.wikipedia.org/wiki/Wisconsin_Counties
# https://no.wikipedia.org/wiki/Liste_over_fylker_i_Wisconsin
# https://pl.wikipedia.org/wiki/Lista_hrabstw_w_stanie_Wisconsin
# https://pt.wikipedia.org/wiki/Lista_de_condados_do_Wisconsin
# https://ro.wikipedia.org/wiki/List%C4%83_de_comitate_din_statul_Wisconsin
# https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BE%D0%BA%D1%80%D1%83%D0%B3%D0%BE%D0%B2_%D0%92%D0%B8%D1%81%D0%BA%D0%BE%D0%BD%D1%81%D0%B8%D0%BD%D0%B0
# https://sq.wikipedia.org/wiki/Qarqe_n%C3%AB_Wisconsin
# https://simple.wikipedia.org/wiki/List_of_counties_in_Wisconsin
# https://sv.wikipedia.org/wiki/Lista_%C3%B6ver_countyn_i_Wisconsin
# https://uk.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BE%D0%BA%D1%80%D1%83%D0%B3%D1%96%D0%B2_%D1%88%D1%82%D0%B0%D1%82%D1%83_%D0%92%D1%96%D1%81%D0%BA%D0%BE%D0%BD%D1%81%D0%B8%D0%BD
# https://ur.wikipedia.org/wiki/%D9%88%D8%B3%DA%A9%D9%88%D9%86%D8%B3%D9%86_%DA%A9%DB%8C_%DA%A9%D8%A7%D8%A4%D9%86%D9%B9%DB%8C%D9%88%DA%BA_%DA%A9%DB%8C_%D9%81%DB%81%D8%B1%D8%B3%D8%AA
# https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_qu%E1%BA%ADn_c%E1%BB%A7a_Wisconsin
# https://zh.wikipedia.org/wiki/%E5%A8%81%E6%96%AF%E5%BA%B7%E6%98%9F%E5%B7%9E%E5%8E%BF%E7%BA%A7%E8%A1%8C%E6%94%BF%E5%8C%BA%E5%88%97%E8%A1%A8
# https://www.wikidata.org/wiki/Special:EntityPage/Q1135704#sitelinks-wikipedia
# /wiki/List_of_counties_in_Wisconsin
# /wiki/Talk:List_of_counties_in_Wisconsin
# /wiki/List_of_counties_in_Wisconsin
# /w/index.php?title=List_of_counties_in_Wisconsin&action=edit
# /w/index.php?title=List_of_counties_in_Wisconsin&action=history
# /wiki/List_of_counties_in_Wisconsin
# /w/index.php?title=List_of_counties_in_Wisconsin&action=edit
# /w/index.php?title=List_of_counties_in_Wisconsin&action=history
# /wiki/Special:WhatLinksHere/List_of_counties_in_Wisconsin
# /wiki/Special:RecentChangesLinked/List_of_counties_in_Wisconsin
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=List_of_counties_in_Wisconsin&oldid=1198793427
# /w/index.php?title=List_of_counties_in_Wisconsin&action=info
# /w/index.php?title=Special:CiteThisPage&page=List_of_counties_in_Wisconsin&id=1198793427&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FList_of_counties_in_Wisconsin
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FList_of_counties_in_Wisconsin
# https://www.wikidata.org/wiki/Special:EntityPage/Q1135704
# /w/index.php?title=Special:DownloadAsPdf&page=List_of_counties_in_Wisconsin&action=show-download-screen
# /w/index.php?title=List_of_counties_in_Wisconsin&printable=yes
# https://commons.wikimedia.org/wiki/Category:Counties_of_Wisconsin
# /wiki/File:Wisconsin-counties-map.gif
# /wiki/State_of_Wisconsin
# /wiki/Menominee_County,_Wisconsin
# /wiki/Milwaukee_County,_Wisconsin
# /wiki/Pepin_County,_Wisconsin
# /wiki/Marathon_County,_Wisconsin
# /wiki/County_government
# /wiki/County_(United_States)
# /wiki/U.S._state
# /wiki/Wisconsin
# /wiki/Treaty_of_Paris_(1783)
# #cite_note-HistoryBuffaloPepinCounties-1
# /wiki/Northwest_Territory
# /wiki/St._Clair_County,_Illinois
# #cite_note-HistoryBuffaloPepinCounties-1
# /wiki/Illinois
# /wiki/Territory_of_Michigan
# /wiki/Brown_County,_Wisconsin
# /wiki/Lake_Michigan
# /wiki/Crawford_County,_Wisconsin
# /wiki/Mississippi_River
# #cite_note-HistoryBuffaloPepinCounties-1
# /wiki/Iowa_County,_Wisconsin
# /wiki/Wisconsin_River
# #cite_note-HistoryBuffaloPepinCounties-1
# /wiki/Milwaukee_County,_Wisconsin
# #cite_note-HistoryBuffaloPepinCounties-1
# /wiki/Wisconsin_Territory
# /wiki/Milwaukee_County,_Wisconsin
# #cite_note-cen-2
# /wiki/Menominee_County,_Wisconsin
# /wiki/Menominee_Indian_Reservation
# #cite_note-cen-2
# /wiki/Pepin_County,_Wisconsin
# /wiki/Marathon_County,_Wisconsin
# #cite_note-cen-2
# /wiki/Federal_Information_Processing_Standard
# #cite_note-3
# #cite_note-epa-4
# /w/index.php?title=List_of_counties_in_Wisconsin&action=edit&section=1
# /wiki/County_seat
# /wiki/Wisconsin_Circuit_Court
# /wiki/County_executive
# #cite_note-5
# /wiki/Brown_County,_Wisconsin
# /wiki/Chippewa_County,_Wisconsin
# /wiki/Dane_County,_Wisconsin
# /wiki/Fond_du_Lac_County,_Wisconsin
# /wiki/Kenosha_County,_Wisconsin
# /wiki/Manitowoc_County,_Wisconsin
# /wiki/Milwaukee_County,_Wisconsin
# /wiki/Outagamie_County,_Wisconsin
# /wiki/Portage_County,_Wisconsin
# /wiki/Racine_County,_Wisconsin
# /wiki/Sawyer_County,_Wisconsin
# /wiki/Waukesha_County,_Wisconsin
# /wiki/Winnebago_County,_Wisconsin
# #cite_note-6
# /w/index.php?title=List_of_counties_in_Wisconsin&action=edit&section=2
# #cite_note-epa-4
# #cite_note-NACO-7
# #cite_note-8
# #cite_note-WI_Formed-9
# #cite_note-WI_Formed-9
# #cite_note-cen-2
# #cite_note-cen-2
# /wiki/Adams_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55001,00
# /wiki/Friendship_(village),_Wisconsin
# /wiki/Portage_County,_Wisconsin
# /wiki/John_Quincy_Adams
# /wiki/President_of_the_United_States
# /wiki/File:Map_of_Wisconsin_highlighting_Adams_County.svg
# /wiki/Ashland_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55003,00
# /wiki/Ashland,_Wisconsin
# /wiki/Ashland,_The_Henry_Clay_Estate
# /wiki/Henry_Clay
# /wiki/Kentucky
# /wiki/File:Map_of_Wisconsin_highlighting_Ashland_County.svg
# /wiki/Barron_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55005,00
# /wiki/Barron,_Wisconsin
# /wiki/Polk_County,_Wisconsin
# /wiki/Henry_D._Barron
# /wiki/Wisconsin_State_Senate
# /wiki/United_States_circuit_court
# /wiki/File:Map_of_Wisconsin_highlighting_Barron_County.svg
# /wiki/Bayfield_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55007,00
# /wiki/Washburn,_Wisconsin
# /wiki/St._Croix_County,_Wisconsin
# /wiki/Henry_Bayfield
# /wiki/Royal_Navy
# /wiki/Great_Lakes
# /wiki/File:Map_of_Wisconsin_highlighting_Bayfield_County.svg
# /wiki/Brown_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55009,00
# /wiki/Green_Bay,_Wisconsin
# /wiki/Territories_of_the_United_States#Formerly_unorganized_territories
# /wiki/Major_general_(United_States)
# /wiki/Jacob_Brown_(general)
# /wiki/United_States_Army
# /wiki/War_of_1812
# /wiki/File:Map_of_Wisconsin_highlighting_Brown_County.svg
# /wiki/Buffalo_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55011,00
# /wiki/Alma,_Wisconsin
# /wiki/Jackson_County,_Wisconsin
# /wiki/Buffalo_River_(Wisconsin)
# /wiki/File:Map_of_Wisconsin_highlighting_Buffalo_County.svg
# /wiki/Burnett_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55013,00
# /wiki/Siren,_Wisconsin
# /wiki/Polk_County,_Wisconsin
# /wiki/Thomas_P._Burnett
# /wiki/Wisconsin_Legislature
# /wiki/File:Map_of_Wisconsin_highlighting_Burnett_County.svg
# /wiki/Calumet_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55015,00
# /wiki/Chilton,_Wisconsin
# /wiki/Menominee
# /wiki/Ceremonial_pipe
# /wiki/File:Map_of_Wisconsin_highlighting_Calumet_County.svg
# /wiki/Chippewa_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55017,00
# /wiki/Chippewa_Falls,_Wisconsin
# /wiki/Crawford_County,_Wisconsin
# /wiki/Ojibwe
# /wiki/File:Map_of_Wisconsin_highlighting_Chippewa_County.svg
# /wiki/Clark_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55019,00
# /wiki/Neillsville,_Wisconsin
# /wiki/Crawford_County,_Wisconsin
# /wiki/George_Rogers_Clark
# /wiki/American_Revolutionary_War
# /wiki/General_officer
# /wiki/File:Map_of_Wisconsin_highlighting_Clark_County.svg
# /wiki/Columbia_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55021,00
# /wiki/Portage,_Wisconsin
# /wiki/Portage_County,_Wisconsin
# /wiki/Christopher_Columbus
# /wiki/File:Map_of_Wisconsin_highlighting_Columbia_County.svg
# /wiki/Crawford_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55023,00
# /wiki/Prairie_du_Chien,_Wisconsin
# /wiki/William_Harris_Crawford
# /wiki/United_States_Congressional_Delegations_from_Georgia
# /wiki/United_States_Secretary_of_the_Treasury
# /wiki/File:Map_of_Wisconsin_highlighting_Crawford_County.svg
# /wiki/Dane_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55025,00
# /wiki/Madison,_Wisconsin
# /wiki/Nathan_Dane
# /wiki/First_Continental_Congress
# /wiki/File:Map_of_Wisconsin_highlighting_Dane_County.svg
# /wiki/Dodge_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55027,00
# /wiki/Juneau,_Wisconsin
# /wiki/Henry_Dodge
# /wiki/List_of_Governors_of_Wisconsin#Governors_of_Wisconsin_Territory
# /wiki/File:Map_of_Wisconsin_highlighting_Dodge_County.svg
# /wiki/Door_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55029,00
# /wiki/Sturgeon_Bay,_Wisconsin
# /wiki/Brown_County,_Wisconsin
# /wiki/Door_Peninsula
# /wiki/Porte_des_Morts
# /wiki/French_language
# /wiki/File:Map_of_Wisconsin_highlighting_Door_County.svg
# /wiki/Douglas_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55031,00
# /wiki/Superior,_Wisconsin
# /wiki/Stephen_Douglas
# /wiki/United_States_Senator
# /wiki/File:Map_of_Wisconsin_highlighting_Douglas_County.svg
# /wiki/Dunn_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55033,00
# /wiki/Menomonie,_Wisconsin
# /wiki/Chippewa_County,_Wisconsin
# /wiki/Charles_Dunn_(Wisconsin_politician)
# /wiki/Wisconsin_Senate
# /wiki/Chief_justice
# /wiki/Wisconsin_Territory
# /wiki/File:Map_of_Wisconsin_highlighting_Dunn_County.svg
# /wiki/Eau_Claire_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55035,00
# /wiki/Eau_Claire,_Wisconsin
# /wiki/Chippewa_County,_Wisconsin
# /wiki/Eau_Claire,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Eau_Claire_County.svg
# /wiki/Florence_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55037,00
# /wiki/Florence_(CDP),_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Florence_County.svg
# /wiki/Fond_du_Lac_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55039,00
# /wiki/Fond_du_Lac,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Fond_du_Lac_County.svg
# /wiki/Forest_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55041,00
# /wiki/Crandon,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Forest_County.svg
# /wiki/Grant_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55043,00
# /wiki/Lancaster,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Grant_County.svg
# /wiki/Green_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55045,00
# /wiki/Monroe,_Wisconsin
# /wiki/Nathanael_Greene
# /wiki/Quartermaster_general
# /wiki/American_Revolutionary_War
# /wiki/File:Map_of_Wisconsin_highlighting_Green_County.svg
# /wiki/Green_Lake_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55047,00
# /wiki/Green_Lake,_Wisconsin
# /wiki/Green_Lake_(Wisconsin)
# /wiki/File:Map_of_Wisconsin_highlighting_Green_Lake_County.svg
# /wiki/Iowa_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55049,00
# /wiki/Dodgeville,_Wisconsin
# /wiki/Iowa_tribe
# /wiki/Indigenous_peoples_of_the_Americas
# /wiki/File:Map_of_Wisconsin_highlighting_Iowa_County.svg
# /wiki/Iron_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55051,00
# /wiki/Hurley,_Wisconsin
# /wiki/Iron
# /wiki/File:Map_of_Wisconsin_highlighting_Iron_County.svg
# /wiki/Jackson_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55053,00
# /wiki/Black_River_Falls,_Wisconsin
# /wiki/Andrew_Jackson
# /wiki/President_of_the_United_States
# /wiki/File:Map_of_Wisconsin_highlighting_Jackson_County.svg
# /wiki/Jefferson_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55055,00
# /wiki/Jefferson,_Wisconsin
# /wiki/Thomas_Jefferson
# /wiki/President_of_the_United_States
# /wiki/File:Map_of_Wisconsin_highlighting_Jefferson_County.svg
# /wiki/Juneau_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55057,00
# /wiki/Mauston,_Wisconsin
# /wiki/Solomon_Juneau
# /wiki/Milwaukee,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Juneau_County.svg
# /wiki/Kenosha_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55059,00
# /wiki/Kenosha,_Wisconsin
# /wiki/Indigenous_peoples_of_the_Americas
# /wiki/Esox
# /wiki/File:Map_of_Wisconsin_highlighting_Kenosha_County.svg
# /wiki/Kewaunee_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55061,00
# /wiki/Kewaunee,_Wisconsin
# /wiki/Potawatomi_language
# /wiki/Ojibwe_language
# /wiki/Greater_Prairie_Chicken
# /wiki/Duck
# /wiki/File:Map_of_Wisconsin_highlighting_Kewaunee_County.svg
# /wiki/La_Crosse_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55063,00
# /wiki/La_Crosse,_Wisconsin
# /wiki/Indigenous_peoples_of_the_Americas
# /wiki/Lacrosse
# /wiki/File:Map_of_Wisconsin_highlighting_La_Crosse_County.svg
# /wiki/Lafayette_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55065,00
# /wiki/Darlington,_Wisconsin
# /wiki/Gilbert_du_Motier,_Marquis_de_Lafayette
# /wiki/Marquis_de_La_Fayette
# /wiki/General_officer
# /wiki/American_Revolutionary_War
# /wiki/File:Map_of_Wisconsin_highlighting_Lafayette_County.svg
# /wiki/Langlade_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55067,00
# /wiki/Antigo,_Wisconsin
# /wiki/Charles_de_Langlade
# /wiki/American_Revolutionary_War
# /wiki/United_States_Indian_Agent
# /wiki/File:Map_of_Wisconsin_highlighting_Langlade_County.svg
# /wiki/Lincoln_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55069,00
# /wiki/Merrill,_Wisconsin
# /wiki/Marathon_County,_Wisconsin
# /wiki/Abraham_Lincoln
# /wiki/President_of_the_United_States
# /wiki/File:Map_of_Wisconsin_highlighting_Lincoln_County.svg
# /wiki/Manitowoc_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55071,00
# /wiki/Manitowoc,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Manitowoc_County.svg
# /wiki/Marathon_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55073,00
# /wiki/Wausau,_Wisconsin
# /wiki/Portage_County,_Wisconsin
# /wiki/Marathon,_Greece
# /wiki/File:Map_of_Wisconsin_highlighting_Marathon_County.svg
# /wiki/Marinette_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55075,00
# /wiki/Marinette,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Marinette_County.svg
# /wiki/Marquette_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55077,00
# /wiki/Montello,_Wisconsin
# /wiki/Jacques_Marquette
# /wiki/File:Map_of_Wisconsin_highlighting_Marquette_County.svg
# /wiki/Menominee_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55078,00
# /wiki/Keshena,_Wisconsin
# /wiki/Menominee_Indian_Reservation
# /wiki/Menominee
# /wiki/File:Map_of_Wisconsin_highlighting_Menominee_County.svg
# /wiki/Milwaukee_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55079,00
# /wiki/Milwaukee,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Milwaukee_County.svg
# /wiki/Monroe_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55081,00
# /wiki/Sparta,_Wisconsin
# /wiki/James_Monroe
# /wiki/President_of_the_United_States
# /wiki/File:Map_of_Wisconsin_highlighting_Monroe_County.svg
# /wiki/Oconto_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55083,00
# /wiki/Oconto,_Wisconsin
# /wiki/Oconto_River
# /wiki/File:Map_of_Wisconsin_highlighting_Oconto_County.svg
# /wiki/Oneida_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55085,00
# /wiki/Rhinelander,_Wisconsin
# /wiki/Oneida_tribe
# /wiki/File:Map_of_Wisconsin_highlighting_Oneida_County.svg
# /wiki/Outagamie_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55087,00
# /wiki/Appleton,_Wisconsin
# /wiki/Outagamie
# /wiki/File:Map_of_Wisconsin_highlighting_Outagamie_County.svg
# /wiki/Ozaukee_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55089,00
# /wiki/Port_Washington,_Wisconsin
# /wiki/Ojibwe
# /wiki/Sauk_people
# /wiki/File:Map_of_Wisconsin_highlighting_Ozaukee_County.svg
# /wiki/Pepin_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55091,00
# /wiki/Durand,_Wisconsin
# /wiki/Dunn_County,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Pepin_County.svg
# /wiki/Pierce_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55093,00
# /wiki/Ellsworth,_Wisconsin
# /wiki/Franklin_Pierce
# /wiki/President_of_the_United_States
# /wiki/File:Map_of_Wisconsin_highlighting_Pierce_County.svg
# /wiki/Polk_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55095,00
# /wiki/Balsam_Lake,_Wisconsin
# /wiki/James_Polk
# /wiki/President_of_the_United_States
# /wiki/File:Map_of_Wisconsin_highlighting_Polk_County.svg
# /wiki/Portage_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55097,00
# /wiki/Stevens_Point,_Wisconsin
# /wiki/Portage_Canal
# /wiki/Fox_River_(Wisconsin)
# /wiki/Wisconsin_River
# /wiki/File:Map_of_Wisconsin_highlighting_Portage_County.svg
# /wiki/Price_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55099,00
# /wiki/Phillips,_Wisconsin
# /wiki/William_T._Price
# /wiki/United_States_Congressional_Delegations_from_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Price_County.svg
# /wiki/Racine_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55101,00
# /wiki/Racine,_Wisconsin
# /wiki/Root_River_(Wisconsin)
# /wiki/File:Map_of_Wisconsin_highlighting_Racine_County.svg
# /wiki/Richland_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55103,00
# /wiki/Richland_Center,_Wisconsin
# /wiki/Iowa_County,_Wisconsin
# /wiki/Soil
# /wiki/File:Map_of_Wisconsin_highlighting_Richland_County.svg
# /wiki/Rock_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55105,00
# /wiki/Janesville,_Wisconsin
# /wiki/Rock_River_(Mississippi_River)
# /wiki/File:Map_of_Wisconsin_highlighting_Rock_County.svg
# /wiki/Rusk_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55107,00
# /wiki/Ladysmith,_Wisconsin
# /wiki/Jeremiah_McLain_Rusk
# /wiki/Governor_of_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Rusk_County.svg
# /wiki/Sauk_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55111,00
# /wiki/Baraboo,_Wisconsin
# /wiki/Sauk_people
# /wiki/File:Map_of_Wisconsin_highlighting_Sauk_County.svg
# /wiki/Sawyer_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55113,00
# /wiki/Hayward,_Wisconsin
# /wiki/Philetus_Sawyer
# /wiki/United_States_Congressional_Delegations_from_Wisconsin
# /wiki/United_States_Congressional_Delegations_from_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Sawyer_County.svg
# /wiki/Shawano_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55115,00
# /wiki/Shawano,_Wisconsin
# /wiki/Oconto_County,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Shawano_County.svg
# /wiki/Sheboygan_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55117,00
# /wiki/Sheboygan,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Sheboygan_County.svg
# /wiki/St._Croix_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55109,00
# /wiki/Hudson,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Saint_Croix_County.svg
# /wiki/Taylor_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55119,00
# /wiki/Medford,_Wisconsin
# /wiki/William_Robert_Taylor
# /wiki/Governor_of_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Taylor_County.svg
# /wiki/Trempealeau_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55121,00
# /wiki/Whitehall,_Wisconsin
# /wiki/Hill
# /wiki/Trempealeau_River
# #cite_note-10
# /wiki/File:Map_of_Wisconsin_highlighting_Trempealeau_County.svg
# /wiki/Vernon_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55123,00
# /wiki/Viroqua,_Wisconsin
# /wiki/Mount_Vernon
# /wiki/George_Washington
# /wiki/File:Map_of_Wisconsin_highlighting_Vernon_County.svg
# /wiki/Vilas_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55125,00
# /wiki/Eagle_River,_Wisconsin
# /wiki/William_Freeman_Vilas
# /wiki/American_Civil_War
# /wiki/United_States_Postmaster_General
# /wiki/United_States_Secretary_of_the_Interior
# /wiki/List_of_United_States_Senators_from_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Vilas_County.svg
# /wiki/Walworth_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55127,00
# /wiki/Elkhorn,_Wisconsin
# /wiki/Reuben_Hyde_Walworth
# /wiki/Jurist
# /wiki/New_York_(state)
# /wiki/File:Map_of_Wisconsin_highlighting_Walworth_County.svg
# /wiki/Washburn_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55129,00
# /wiki/Shell_Lake,_Wisconsin
# /wiki/Cadwallader_C._Washburn
# /wiki/Governor_of_Wisconsin
# /wiki/United_States_congressional_delegations_from_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Washburn_County.svg
# /wiki/Washington_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55131,00
# /wiki/West_Bend,_Wisconsin
# /wiki/George_Washington
# /wiki/American_Revolutionary_War
# /wiki/President_of_the_United_States
# /wiki/File:Map_of_Wisconsin_highlighting_Washington_County.svg
# /wiki/Waukesha_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55133,00
# /wiki/Waukesha,_Wisconsin
# /wiki/Pottawatomi
# /wiki/Fox
# /wiki/File:Map_of_Wisconsin_highlighting_Waukesha_County.svg
# /wiki/Waupaca_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55135,00
# /wiki/Waupaca,_Wisconsin
# /wiki/Menominee_language
# /wiki/File:Map_of_Wisconsin_highlighting_Waupaca_County.svg
# /wiki/Waushara_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55137,00
# /wiki/Wautoma,_Wisconsin
# /wiki/File:Map_of_Wisconsin_highlighting_Waushara_County.svg
# /wiki/Winnebago_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55139,00
# /wiki/Oshkosh,_Wisconsin
# /wiki/Winnebago_Indians
# /wiki/File:Map_of_Wisconsin_highlighting_Winnebago_County.svg
# /wiki/Wood_County,_Wisconsin
# http://www.census.gov/quickfacts/table/PST045215/55141,00
# /wiki/Wisconsin_Rapids,_Wisconsin
# /wiki/Portage_County,_Wisconsin
# /wiki/Joseph_Wood_(Wisconsin)
# /wiki/File:Map_of_Wisconsin_highlighting_Wood_County.svg
# /w/index.php?title=List_of_counties_in_Wisconsin&action=edit&section=3
# #cite_note-CountiesByYear-11
# /wiki/Bad_Axe_River
# /wiki/Battle_of_Bad_Axe
# /wiki/Vernon_County,_Wisconsin
# #cite_note-Vernon-12
# /wiki/George_M._Dallas
# /wiki/Barron_County,_Wisconsin
# #cite_note-Barron-13
# #cite_note-14
# /wiki/Rusk_County,_Wisconsin
# #cite_note-15
# /wiki/La_Pointe_County,_Wisconsin
# /wiki/Bayfield_County,_Wisconsin
# #cite_note-16
# /wiki/Oconto_County,_Wisconsin
# #cite_note-17
# /w/index.php?title=List_of_counties_in_Wisconsin&action=edit&section=4
# /wiki/Washington_County,_Wisconsin
# #cite_note-WI_Formed-9
# #cite_note-18
# /wiki/Wood_County,_Wisconsin
# /wiki/Clark_County,_Wisconsin
# /wiki/Marathon_County,_Wisconsin
# /wiki/Marshfield,_Wisconsin
# #cite_note-CenturyCo-19
# /wiki/Sand_mining
# #cite_note-20
# /w/index.php?title=List_of_counties_in_Wisconsin&action=edit&section=5
# /wiki/BOW_counties
# /wiki/WOW_counties
# /wiki/Political_subdivisions_of_Wisconsin
# /wiki/List_of_cities_in_Wisconsin
# /wiki/List_of_villages_in_Wisconsin
# /wiki/List_of_towns_in_Wisconsin
# /w/index.php?title=List_of_counties_in_Wisconsin&action=edit&section=6
# #cite_ref-HistoryBuffaloPepinCounties_1-0
# #cite_ref-HistoryBuffaloPepinCounties_1-1
# #cite_ref-HistoryBuffaloPepinCounties_1-2
# #cite_ref-HistoryBuffaloPepinCounties_1-3
# #cite_ref-HistoryBuffaloPepinCounties_1-4
# https://books.google.com/books?id=SNYqAQAAMAAJ&q=wisconsin+counties+lake+michigan&pg=PA4
# https://web.archive.org/web/20230922115855/https://books.google.com/books?id=SNYqAQAAMAAJ&q=wisconsin+counties+lake+michigan&pg=PA4
# #cite_ref-cen_2-0
# #cite_ref-cen_2-1
# #cite_ref-cen_2-2
# #cite_ref-cen_2-3
# #cite_ref-cen_2-4
# https://www.census.gov/quickfacts/fact/table/WI/PST045219
# https://web.archive.org/web/20211119003300/https://www.census.gov/quickfacts/fact/table/WI/PST045219
# #cite_ref-3
# https://web.archive.org/web/20130929074056/http://www.itl.nist.gov/fipspubs/fip6-4.htm
# http://www.itl.nist.gov/fipspubs/fip6-4.htm
# #cite_ref-epa_4-0
# #cite_ref-epa_4-1
# http://www.epa.gov/enviro/html/codes/wi.html
# https://web.archive.org/web/20131007105136/http://www.epa.gov/enviro/html/codes/wi.html
# #cite_ref-5
# https://docs.legis.wisconsin.gov/misc/lrb/blue_book/2011_2012
# https://web.archive.org/web/20171228171604/https://docs.legis.wisconsin.gov/misc/lrb/blue_book/2011_2012
# /wiki/Wayback_Machine
# #cite_ref-6
# https://docs.legis.wisconsin.gov/misc/lrb/blue_book/2011_2012
# https://web.archive.org/web/20171228171604/https://docs.legis.wisconsin.gov/misc/lrb/blue_book/2011_2012
# /wiki/Wayback_Machine
# #cite_ref-NACO_7-0
# http://www.naco.org/Counties/Pages/FindACounty.aspx
# https://web.archive.org/web/20110531210815/http://www.naco.org/Counties/Pages/FindACounty.
# #cite_ref-8
# https://docs.legis.wisconsin.gov/misc/lrb/blue_book/2011_2012
# https://web.archive.org/web/20171228171604/https://docs.legis.wisconsin.gov/misc/lrb/blue_book/2011_2012
# /wiki/Wayback_Machine
# #cite_ref-WI_Formed_9-0
# #cite_ref-WI_Formed_9-1
# #cite_ref-WI_Formed_9-2
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/1130567257
# https://books.google.com/books?id=nbQTAAAAYAAJ&dq=%27Organization%2C+Boundaries+and+Names+of+Wisconsin+Counties&pg=PA184
# https://web.archive.org/web/20230404010324/https://books.google.com/books?id=nbQTAAAAYAAJ&dq=%27Organization%2C+Boundaries+and+Names+of+Wisconsin+Counties&pg=PA184
# /wiki/Wayback_Machine
# #cite_ref-10
# #cite_ref-CountiesByYear_11-0
# https://web.archive.org/web/20180328102944/https://mapgeeks.org/maps-of-wisconsin/
# https://mapgeeks.org/maps-of-wisconsin/
# #cite_ref-Vernon_12-0
# https://archive.org/details/historyofvernonc01spri
# https://archive.org/details/historyofvernonc01spri/page/132
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/1178120341
# https://books.google.com/books?id=-0EVAAAAYAAJ
# #cite_ref-Barron_13-0
# https://web.archive.org/web/20080824125629/http://www.wisconsinhistory.org/dictionary/index.asp?action=view
# http://www.wisconsinhistory.org/dictionary/index.asp?action=view&term_id=2253&keyword=barron
# #cite_ref-14
# https://archive.org/details/bub_gb_9V1IAAAAMAAJ
# https://archive.org/details/bub_gb_9V1IAAAAMAAJ/page/n134
# #cite_ref-15
# http://ruskcountymuseum.webs.com/gatescountycourthouse.htm
# https://web.archive.org/web/20131022021623/http://ruskcountymuseum.webs.com/gatescountycourthouse.htm
# /wiki/Wayback_Machine
# #cite_ref-16
# http://www.wisconsinhistory.org/dictionary/index.asp?action=view&term_id=9327&keyword=la+pointe
# https://web.archive.org/web/20140508030459/http://www.wisconsinhistory.org/dictionary/index.asp?action=view&term_id=9327&keyword=la+pointe
# #cite_ref-17
# #cite_ref-18
# https://books.google.com/books?id=DGqbAAAAMAAJ&q=tuskola+county+wisconsin&pg=PA77
# https://web.archive.org/web/20230922115855/https://books.google.com/books?id=DGqbAAAAMAAJ&q=tuskola+county+wisconsin&pg=PA77
# #cite_ref-CenturyCo_19-0
# https://journaltimes.com/news/new-county-only-solution-to-poor-service-some-say/article_76708d68-ba6f-5e0d-8862-4a836bee3f63.html
# https://web.archive.org/web/20161105142736/http://journaltimes.com/news/new-county-only-solution-to-poor-service-some-say/article_76708d68-ba6f-5e0d-8862-4a836bee3f63.html
# #cite_ref-20
# https://badgerherald.com/news/2012/03/04/professor-advocates/
# https://web.archive.org/web/20200628145420/https://badgerherald.com/news/2012/03/04/professor-advocates/
# /w/index.php?title=List_of_counties_in_Wisconsin&action=edit&section=7
# http://publications.newberry.org/ahcbp/pages/Wisconsin.html
# /wiki/Newberry_Library
# /wiki/Template:U.S._Counties
# /wiki/Template_talk:U.S._Counties
# /wiki/Special:EditPage/Template:U.S._Counties
# /wiki/List_of_United_States_counties_and_county_equivalents
# /wiki/U.S._state
# /wiki/List_of_counties_in_Alabama
# /wiki/List_of_boroughs_and_census_areas_in_Alaska
# /wiki/List_of_counties_in_Arizona
# /wiki/List_of_counties_in_Arkansas
# /wiki/List_of_counties_in_California
# /wiki/List_of_counties_in_Colorado
# /wiki/List_of_counties_in_Connecticut
# /wiki/Councils_of_governments_in_Connecticut
# /wiki/List_of_counties_in_Delaware
# /wiki/List_of_counties_in_Florida
# /wiki/List_of_counties_in_Georgia
# /wiki/List_of_counties_in_Hawaii
# /wiki/List_of_counties_in_Idaho
# /wiki/List_of_counties_in_Illinois
# /wiki/List_of_counties_in_Indiana
# /wiki/List_of_counties_in_Iowa
# /wiki/List_of_counties_in_Kansas
# /wiki/List_of_counties_in_Kentucky
# /wiki/List_of_parishes_in_Louisiana
# /wiki/List_of_counties_in_Maine
# /wiki/List_of_counties_in_Maryland
# /wiki/List_of_counties_in_Massachusetts
# /wiki/List_of_counties_in_Michigan
# /wiki/List_of_counties_in_Minnesota
# /wiki/List_of_counties_in_Mississippi
# /wiki/List_of_counties_in_Missouri
# /wiki/List_of_counties_in_Montana
# /wiki/List_of_counties_in_Nebraska
# /wiki/List_of_counties_in_Nevada
# /wiki/List_of_counties_in_New_Hampshire
# /wiki/List_of_counties_in_New_Jersey
# /wiki/List_of_counties_in_New_Mexico
# /wiki/List_of_counties_in_New_York
# /wiki/List_of_counties_in_North_Carolina
# /wiki/List_of_counties_in_North_Dakota
# /wiki/List_of_counties_in_Ohio
# /wiki/List_of_counties_in_Oklahoma
# /wiki/List_of_counties_in_Oregon
# /wiki/List_of_counties_in_Pennsylvania
# /wiki/List_of_counties_in_Rhode_Island
# /wiki/List_of_counties_in_South_Carolina
# /wiki/List_of_counties_in_South_Dakota
# /wiki/List_of_counties_in_Tennessee
# /wiki/List_of_counties_in_Texas
# /wiki/List_of_counties_in_Utah
# /wiki/List_of_counties_in_Vermont
# /wiki/List_of_cities_and_counties_in_Virginia
# /wiki/List_of_counties_in_Washington
# /wiki/List_of_counties_in_West_Virginia
# None
# /wiki/List_of_counties_in_Wyoming
# /wiki/Federal_district
# /wiki/Washington,_D.C.
# /wiki/Insular_area
# /wiki/Administrative_divisions_of_American_Samoa
# /wiki/Villages_of_Guam
# /wiki/Northern_Mariana_Islands#Administrative_divisions
# /wiki/Municipalities_of_Puerto_Rico
# /wiki/Districts_and_sub-districts_of_the_United_States_Virgin_Islands
# /wiki/United_States_Minor_Outlying_Islands
# /wiki/United_States_Minor_Outlying_Islands#Islands
# /wiki/Template:Wisconsin
# /wiki/Template_talk:Wisconsin
# /wiki/Special:EditPage/Template:Wisconsin
# /wiki/U.S._state
# /wiki/Wisconsin
# /wiki/Madison,_Wisconsin
# /wiki/Index_of_Wisconsin-related_articles
# /wiki/Outline_of_Wisconsin
# /wiki/Agriculture_in_Wisconsin
# /wiki/Wisconsin_dairy_industry
# /wiki/Climate_change_in_Wisconsin
# /wiki/Geography_of_Wisconsin
# /wiki/List_of_islands_of_Wisconsin
# /wiki/List_of_lakes_of_Wisconsin
# /wiki/List_of_governors_of_Wisconsin
# /wiki/United_States_congressional_delegations_from_Wisconsin
# /wiki/History_of_Wisconsin
# /wiki/List_of_people_from_Wisconsin
# /wiki/Sports_in_Wisconsin
# /wiki/List_of_Wisconsin_state_symbols
# /wiki/Category:Tourist_attractions_in_Wisconsin
# /wiki/Abortion_in_Wisconsin
# /wiki/Administrative_divisions_of_Wisconsin
# /wiki/Cannabis_in_Wisconsin
# /wiki/Crime_in_Wisconsin
# /wiki/Category:Wisconsin_culture
# /wiki/Wisconsin#Demographics
# /wiki/Wisconsin#Economy
# /wiki/Wisconsin#Education
# /wiki/Gun_laws_in_Wisconsin
# /wiki/LGBT_rights_in_Wisconsin
# /wiki/Wisconsin#Politics
# /wiki/Wisconsin#Geography
# /wiki/Apostle_Islands
# /wiki/Central_Plain_(Wisconsin)
# /wiki/Chippewa_Valley
# /wiki/Door_Peninsula
# /wiki/Driftless_Area
# /wiki/Eastern_Ridges_and_Lowlands
# /wiki/Fox_River_(Green_Bay_tributary)
# /wiki/Great_River_Road
# /wiki/Lake_Superior_Lowland
# /wiki/Northern_Highland
# /wiki/Western_Upland
# /wiki/Wisconsin_statistical_areas
# /wiki/Chicago_metropolitan_area
# /wiki/Madison,_Wisconsin,_metropolitan_area
# /wiki/Milwaukee_metropolitan_area
# /wiki/Minneapolis%E2%80%93Saint_Paul
# /wiki/List_of_cities_in_Wisconsin
# /wiki/Appleton,_Wisconsin
# /wiki/Eau_Claire,_Wisconsin
# /wiki/Green_Bay,_Wisconsin
# /wiki/Janesville,_Wisconsin
# /wiki/Kenosha,_Wisconsin
# /wiki/La_Crosse,_Wisconsin
# /wiki/Madison,_Wisconsin
# /wiki/Milwaukee
# /wiki/Oshkosh,_Wisconsin
# /wiki/Racine,_Wisconsin
# /wiki/Waukesha,_Wisconsin
# /wiki/West_Allis,_Wisconsin
# /wiki/List_of_cities_in_Wisconsin
# /wiki/Beaver_Dam,_Wisconsin
# /wiki/Beloit,_Wisconsin
# /wiki/Brookfield,_Wisconsin
# /wiki/Cudahy,_Wisconsin
# /wiki/De_Pere,_Wisconsin
# /wiki/Fitchburg,_Wisconsin
# /wiki/Fond_du_Lac,_Wisconsin
# /wiki/Franklin,_Milwaukee_County,_Wisconsin
# /wiki/Greenfield,_Wisconsin
# /wiki/Hartford,_Wisconsin
# /wiki/Hudson,_Wisconsin
# /wiki/Kaukauna,_Wisconsin
# /wiki/Manitowoc,_Wisconsin
# /wiki/Marshfield,_Wisconsin
# /wiki/Menasha,_Wisconsin
# /wiki/Menomonie,_Wisconsin
# /wiki/Mequon,_Wisconsin
# /wiki/Middleton,_Wisconsin
# /wiki/Muskego,_Wisconsin
# /wiki/Neenah,_Wisconsin
# /wiki/New_Berlin,_Wisconsin
# /wiki/Oak_Creek,_Wisconsin
# /wiki/Oconomowoc,_Wisconsin
# /wiki/Onalaska,_Wisconsin
# /wiki/River_Falls,_Wisconsin
# /wiki/Sheboygan,_Wisconsin
# /wiki/South_Milwaukee,_Wisconsin
# /wiki/Stevens_Point,_Wisconsin
# /wiki/Sun_Prairie,_Wisconsin
# /wiki/Superior,_Wisconsin
# /wiki/Watertown,_Wisconsin
# /wiki/Wausau,_Wisconsin
# /wiki/Wauwatosa,_Wisconsin
# /wiki/West_Bend,_Wisconsin
# /wiki/Wisconsin_Rapids,_Wisconsin
# /wiki/List_of_villages_in_Wisconsin
# /wiki/Ashwaubenon,_Wisconsin
# /wiki/Bellevue,_Wisconsin
# /wiki/Caledonia,_Wisconsin
# /wiki/Fox_Crossing,_Wisconsin
# /wiki/Germantown,_Wisconsin
# /wiki/Howard,_Wisconsin
# /wiki/Menomonee_Falls,_Wisconsin
# /wiki/Mount_Pleasant,_Wisconsin
# /wiki/Pleasant_Prairie,_Wisconsin
# None
# /wiki/Adams_County,_Wisconsin
# /wiki/Ashland_County,_Wisconsin
# /wiki/Barron_County,_Wisconsin
# /wiki/Bayfield_County,_Wisconsin
# /wiki/Brown_County,_Wisconsin
# /wiki/Buffalo_County,_Wisconsin
# /wiki/Burnett_County,_Wisconsin
# /wiki/Calumet_County,_Wisconsin
# /wiki/Chippewa_County,_Wisconsin
# /wiki/Clark_County,_Wisconsin
# /wiki/Columbia_County,_Wisconsin
# /wiki/Crawford_County,_Wisconsin
# /wiki/Dane_County,_Wisconsin
# /wiki/Dodge_County,_Wisconsin
# /wiki/Door_County,_Wisconsin
# /wiki/Douglas_County,_Wisconsin
# /wiki/Dunn_County,_Wisconsin
# /wiki/Eau_Claire_County,_Wisconsin
# /wiki/Florence_County,_Wisconsin
# /wiki/Fond_du_Lac_County,_Wisconsin
# /wiki/Forest_County,_Wisconsin
# /wiki/Grant_County,_Wisconsin
# /wiki/Green_County,_Wisconsin
# /wiki/Green_Lake_County,_Wisconsin
# /wiki/Iowa_County,_Wisconsin
# /wiki/Iron_County,_Wisconsin
# /wiki/Jackson_County,_Wisconsin
# /wiki/Jefferson_County,_Wisconsin
# /wiki/Juneau_County,_Wisconsin
# /wiki/Kenosha_County,_Wisconsin
# /wiki/Kewaunee_County,_Wisconsin
# /wiki/La_Crosse_County,_Wisconsin
# /wiki/Lafayette_County,_Wisconsin
# /wiki/Langlade_County,_Wisconsin
# /wiki/Lincoln_County,_Wisconsin
# /wiki/Manitowoc_County,_Wisconsin
# /wiki/Marathon_County,_Wisconsin
# /wiki/Marinette_County,_Wisconsin
# /wiki/Marquette_County,_Wisconsin
# /wiki/Menominee_County,_Wisconsin
# /wiki/Milwaukee_County,_Wisconsin
# /wiki/Monroe_County,_Wisconsin
# /wiki/Oconto_County,_Wisconsin
# /wiki/Oneida_County,_Wisconsin
# /wiki/Outagamie_County,_Wisconsin
# /wiki/Ozaukee_County,_Wisconsin
# /wiki/Pepin_County,_Wisconsin
# /wiki/Pierce_County,_Wisconsin
# /wiki/Polk_County,_Wisconsin
# /wiki/Portage_County,_Wisconsin
# /wiki/Price_County,_Wisconsin
# /wiki/Racine_County,_Wisconsin
# /wiki/Richland_County,_Wisconsin
# /wiki/Rock_County,_Wisconsin
# /wiki/Rusk_County,_Wisconsin
# /wiki/Sauk_County,_Wisconsin
# /wiki/Sawyer_County,_Wisconsin
# /wiki/Shawano_County,_Wisconsin
# /wiki/Sheboygan_County,_Wisconsin
# /wiki/St._Croix_County,_Wisconsin
# /wiki/Taylor_County,_Wisconsin
# /wiki/Trempealeau_County,_Wisconsin
# /wiki/Vernon_County,_Wisconsin
# /wiki/Vilas_County,_Wisconsin
# /wiki/Walworth_County,_Wisconsin
# /wiki/Washburn_County,_Wisconsin
# /wiki/Washington_County,_Wisconsin
# /wiki/Waukesha_County,_Wisconsin
# /wiki/Waupaca_County,_Wisconsin
# /wiki/Waushara_County,_Wisconsin
# /wiki/Winnebago_County,_Wisconsin
# /wiki/Wood_County,_Wisconsin
# /wiki/Portal:Wisconsin
# https://en.wikipedia.org/w/index.php?title=List_of_counties_in_Wisconsin&oldid=1198793427
# /wiki/Help:Category
# /wiki/Category:Lists_of_counties_of_the_United_States_by_state
# /wiki/Category:Wisconsin_counties
# /wiki/Category:Wisconsin_geography-related_lists
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=List_of_counties_in_Wisconsin&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
tables = soup.find_all('table')

# %%
for table in tables:
    # Extrat rows
    rows = table.find_all('tr')
    
    table_data = []
    
    for row in rows:
        # Extract cells
        cells = row.find_all(['td','th'])
        
        row_data = [cell.get_text(strip=True) for cell in cells]
        table_data.append(row_data)
        
# Print the extracted table data
print(table_data)
# Out:
# [['vteStateofWisconsin'], ['Madison(capital)'], ['Topics', 'OutlineAgricultureDairy industryClimate changeGeographyIslandsLakesGovernorsDelegationsHistoryPeopleSportsSymbolsTourist attractions'], ['Society', 'AbortionAdministrative divisionsCannabisCrimeCultureDemographicsEconomyEducationGun lawsLGBT rightsPolitics'], ['Regions', 'Apostle IslandsCentral PlainChippewa ValleyDoor PeninsulaDriftless AreaEastern Ridges and LowlandsFox River ValleyGreat River RoadLake Superior LowlandNorthern HighlandWestern Upland'], ['Major metropolitan areas(pop. over 500,000)', 'Chicago metropolitan areaMadison metropolitan areaMilwaukee metropolitan areaTwin Cities metropolitan area'], ['Largest cities(pop. over 50,000)', 'AppletonEau ClaireGreen BayJanesvilleKenoshaLa CrosseMadisonMilwaukeeOshkoshRacineWaukeshaWest Allis'], ['Smaller cities(pop. 15,000 to 50,000)', 'Beaver DamBeloitBrookfieldCudahyDe PereFitchburgFond du LacFranklinGreenfieldHartfordHudsonKaukaunaManitowocMarshfieldMenashaMenomonieMequonMiddletonMuskegoNeenahNew BerlinOak CreekOconomowocOnalaskaRiver FallsSheboyganSouth MilwaukeeStevens PointSun PrairieSuperiorWatertownWausauWauwatosaWest BendWisconsin Rapids'], ['Largest villages(pop. over 15,000)', 'AshwaubenonBellevueCaledoniaFox CrossingGermantownHowardMenomonee FallsMount PleasantPleasant Prairie'], ['Counties', 'AdamsAshlandBarronBayfieldBrownBuffaloBurnettCalumetChippewaClarkColumbiaCrawfordDaneDodgeDoorDouglasDunnEau ClaireFlorenceFond du LacForestGrantGreenGreen LakeIowaIronJacksonJeffersonJuneauKenoshaKewauneeLa CrosseLafayetteLangladeLincolnManitowocMarathonMarinetteMarquetteMenomineeMilwaukeeMonroeOcontoOneidaOutagamieOzaukeePepinPiercePolkPortagePriceRacineRichlandRockRuskSaukSawyerShawanoSheboyganSt. CroixTaylorTrempealeauVernonVilasWalworthWashburnWashingtonWaukeshaWaupacaWausharaWinnebagoWood'], ['Wisconsin portal']]

# %%
# Create a map centered around Wisconsin
map_wisconsin = folium.Map(location=[43.7844, -88.7879], zoom_start=7)

# %%
# Add pinpoint markers for specific locations
folium.Marker([43.0731, -89.4012], popup='Madison, WI').add_to(map_wisconsin)
folium.Marker([43.0389, -87.9065], popup='Milwaukee, WI').add_to(map_wisconsin)
# Add more markers as needed

# %%
# Display the map
map_wisconsin
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32c9a7d51d69d85429e45ff44d9b30ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32c9a7d51d69d85429e45ff44d9b30ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32c9a7d51d69d85429e45ff44d9b30ba = L.map(
#                 &quot;map_32c9a7d51d69d85429e45ff44d9b30ba&quot;,
#                 {
#                     center: [43.7844, -88.7879],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cdd708c5938bd217bc346f41a238b1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8cdd708c5938bd217bc346f41a238b1a.addTo(map_32c9a7d51d69d85429e45ff44d9b30ba);
#
#
#             var marker_3f52537f57343b9beb6c94c840710d4d = L.marker(
#                 [43.0731, -89.4012],
#                 {}
#             ).addTo(map_32c9a7d51d69d85429e45ff44d9b30ba);
#
#
#         var popup_05f84323c3252933213f398045d1e712 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5eeda2f07041f4e233bc6ed9544ddf12 = $(`&lt;div id=&quot;html_5eeda2f07041f4e233bc6ed9544ddf12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Madison, WI&lt;/div&gt;`)[0];
#                 popup_05f84323c3252933213f398045d1e712.setContent(html_5eeda2f07041f4e233bc6ed9544ddf12);
#
#
#
#         marker_3f52537f57343b9beb6c94c840710d4d.bindPopup(popup_05f84323c3252933213f398045d1e712)
#         ;
#
#
#
#
#             var marker_066a16bf97002376b394b95bb61fac8a = L.marker(
#                 [43.0389, -87.9065],
#                 {}
#             ).addTo(map_32c9a7d51d69d85429e45ff44d9b30ba);
#
#
#         var popup_b60cdf00d42acabaf71c09657e04f999 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed87d68a48a519cc1252be9fdabc5b35 = $(`&lt;div id=&quot;html_ed87d68a48a519cc1252be9fdabc5b35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Milwaukee, WI&lt;/div&gt;`)[0];
#                 popup_b60cdf00d42acabaf71c09657e04f999.setContent(html_ed87d68a48a519cc1252be9fdabc5b35);
#
#
#
#         marker_066a16bf97002376b394b95bb61fac8a.bindPopup(popup_b60cdf00d42acabaf71c09657e04f999)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from geopy.geocoders import Nominatim

# Create a map centered around Wisconsin
map_wisconsin = folium.Map(location=[43.7844, -88.7879], zoom_start=7)

# Extract county names from the list
counties_list = ['Adams', 'Ashland', 'Barron', 'Bayfield', 'Brown', 'Buffalo', 'Burnett', 'Calumet', 'Chippewa', 'Clark', 'Columbia', 'Crawford', 'Dane', 'Dodge', 'Door', 'Douglas', 'Dunn', 'Eau Claire', 'Florence', 'Fond du Lac', 'Forest', 'Grant', 'Green', 'Green Lake', 'Iowa', 'Iron', 'Jackson', 'Jefferson', 'Juneau', 'Kenosha', 'Kewaunee', 'La Crosse', 'Lafayette', 'Langlade', 'Lincoln', 'Manitowoc', 'Marathon', 'Marinette', 'Marquette', 'Menominee', 'Milwaukee', 'Monroe', 'Oconto', 'Oneida', 'Outagamie', 'Ozaukee', 'Pepin', 'Pierce', 'Polk', 'Portage', 'Price', 'Racine', 'Richland', 'Rock', 'Rusk', 'Sauk', 'Sawyer', 'Shawano', 'Sheboygan', 'St. Croix', 'Taylor', 'Trempealeau', 'Vernon', 'Vilas', 'Walworth', 'Washburn', 'Washington', 'Waukesha', 'Waupaca', 'Waushara', 'Winnebago', 'Wood']

# Initialize a geocoder
geolocator = Nominatim(user_agent="my_geocoder")

# Iterate over each county and add a marker for it
for county in counties_list:
    # Geocode county location
    location = geolocator.geocode(county + ', Wisconsin')
    if location:
        # Add marker for the county
        folium.Marker([location.latitude, location.longitude], popup=county).add_to(map_wisconsin)

# Display the map
map_wisconsin
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea358b82cc1162d29565b7448763c905 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea358b82cc1162d29565b7448763c905&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea358b82cc1162d29565b7448763c905 = L.map(
#                 &quot;map_ea358b82cc1162d29565b7448763c905&quot;,
#                 {
#                     center: [43.7844, -88.7879],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19a815034d5a3d48a6568fc6f5902872 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_19a815034d5a3d48a6568fc6f5902872.addTo(map_ea358b82cc1162d29565b7448763c905);
#
#
#             var marker_68f02d94a02f0a2baf4f503a9ec6e1af = L.marker(
#                 [43.9462246, -89.7836456],
#                 {}
#             ).addTo(map_ea358b82cc1162d29565b7448763c905);
#
#
#         var popup_5e0b55b22053966f50edb438daca1aa7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d884b6059c8b5ab68eb40a8963488c8 = $(`&lt;div id=&quot;html_2d884b6059c8b5ab68eb40a8963488c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adams&lt;/div&gt;`)[0];
#                 popup_5e0b55b22053966f50edb438daca1aa7.setContent(html_2d884b6059c8b5ab68eb40a8963488c8);
#
#
#
#         marker_68f02d94a02f0a2baf4f503a9ec6e1af.bindPopup(popup_5e0b55b22053966f50edb438daca1aa7)
#         ;
#
#
#
#
#             var marker_de09f1faf0e67f73545fbb03f398901a = L.marker(
#                 [46.2062319, -90.6802594],
#                 {}
#             ).addTo(map_ea358b82cc1162d29565b7448763c905);
#
#
#         var popup_c605fc6e506fb94d472d7c6b85f05e4a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04ee4f88ad94285234bc1d78c1a2f09e = $(`&lt;div id=&quot;html_04ee4f88ad94285234bc1d78c1a2f09e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ashland&lt;/div&gt;`)[0];
#                 popup_c605fc6e506fb94d472d7c6b85f05e4a.setContent(html_04ee4f88ad94285234bc1d78c1a2f09e);
#
#
#
#         marker_de09f1faf0e67f73545fbb03f398901a.bindPopup(popup_c605fc6e506fb94d472d7c6b85f05e4a)
#         ;
#
#
#
#
#             var marker_b46c267ba69ae3a1ed6c313fcbae490e = L.marker(
#                 [45.423557, -91.8454099],
#                 {}
#             ).addTo(map_ea358b82cc1162d29565b7448763c905);
#
#
#         var popup_164aecc90809241c971d79d554eeedf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c4a933e6268c66f9dd8ff76697e33de = $(`&lt;div id=&quot;html_7c4a933e6268c66f9dd8ff76697e33de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barron&lt;/div&gt;`)[0];
#                 popup_164aecc90809241c971d79d554eeedf1.setContent(html_7c4a933e6268c66f9dd8ff76697e33de);
#
#
#
#         marker_b46c267ba69ae3a1ed6c313fcbae490e.bindPopup(popup_164aecc90809241c971d79d554eeedf1)
#         ;
#
#
#
#
#             var marker_75ebdaa0c154492c152d3d90e306be7b = L.marker(
#                 [46.4710241, -91.1983175],
#                 {}
#             ).addTo(map_ea358b82cc1162d29565b7448763c905);
#
#
#         var popup_a97aea176d138fc58ed13e39ea573b80 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f24abd67ccc2a3da796d73f163e586fb = $(`&lt;div id=&quot;html_f24abd67ccc2a3da796d73f163e586fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bayfield&lt;/div&gt;`)[0];
#                 popup_a97aea176d138fc58ed13e39ea573b80.setContent(html_f24abd67ccc2a3da796d73f163e586fb);
#
#
#
#         marker_75ebdaa0c154492c152d3d90e306be7b.bindPopup(popup_a97aea176d138fc58ed13e39ea573b80)
#         ;
#
#
#
#
#             var marker_1cbf9e1a857218441db2e611bc10c3d0 = L.marker(
#                 [44.4383498, -88.0167093],
#                 {}
#             ).addTo(map_ea358b82cc1162d29565b7448763c905);
#
#
#         var popup_e1b9984e0af59ed6ed906bb8cf734775 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7cbf9a52bdf19603a75716647ec9c641 = $(`&lt;div id=&quot;html_7cbf9a52bdf19603a75716647ec9c641&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brown&lt;/div&gt;`)[0];
#                 popup_e1b9984e0af59ed6ed906bb8cf734775.setContent(html_7cbf9a52bdf19603a75716647ec9c641);
#
#
#
#         marker_1cbf9e1a857218441db2e611bc10c3d0.bindPopup(popup_e1b9984e0af59ed6ed906bb8cf734775)
#         ;
#
#
#
#
#             var marker_8272a03fa037e94ebc217cc3771c14f3 = L.marker(
#                 [44.4073658, -91.7547858],
#                 {}
#             ).addTo(map_ea358b82cc1162d29565b7448763c905);
#
#
#         var p
